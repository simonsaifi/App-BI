# %% [markdown]
# # correction des données

# %%
import pandas as pd

def explorer_corriger_nettoyer_csv(chemin_fichier_csv):
    # Charger le fichier CSV dans un DataFrame
    df = pd.read_csv(chemin_fichier_csv)

    # Explorer les premières lignes du DataFrame
    print("Aperçu des premières lignes du DataFrame:")
    print(df.head())

    # Explorer les informations sur le DataFrame
    print("\nInformations sur le DataFrame:")
    print(df.info())

    # Explorer les statistiques descriptives
    print("\nStatistiques descriptives:")
    print(df.describe())

    # Corriger les données si nécessaire
    # Remplacer les valeurs manquantes par la moyenne des colonnes numériques
    colonnes_numeriques = df.select_dtypes(include=['number']).columns
    df[colonnes_numeriques] = df[colonnes_numeriques].fillna(df[colonnes_numeriques].mean())

    # Nettoyer les données si nécessaire
    # Supprimer les lignes dupliquées
    df.drop_duplicates(inplace=True)

    # Enregistrer le DataFrame modifié dans un nouveau fichier CSV
    nouveau_chemin_fichier_csv = chemin_fichier_csv.replace('.csv', '_modifie.csv')
    df.to_csv(nouveau_chemin_fichier_csv, index=False)

    print(f"\nLes données ont été corrigées et nettoyées. Nouveau fichier CSV enregistré à : {nouveau_chemin_fichier_csv}")

# Remplacez 'votre_fichier.csv' par le chemin de votre fichier CSV
explorer_corriger_nettoyer_csv('Foppa1.1.2_csv/Agents.csv')
# Out:
# Aperçu des premières lignes du DataFrame:
#    agentId                                name         siret  \
# 0        0                              #APTIC  8.445059e+13
# 1        1                       LEGALLAIS SAS           NaN
# 2        2               SOCIETE CORSE TRAVAUX  3.304645e+13
# 3        3         BECTON DICKINSON FRANCE SAS           NaN
# 4        4  ACOORD CADRE MULTI ATTRIBUTAIRES 1           NaN
#
#                     address          city  zipcode country department  \
# 0       87 QUAI DE QUEYRIES      BORDEAUX  33100.0      FR         33
# 1                 TSA 70004         CAEN;      NaN     NaN        NaN
# 2                    RN 200        ALERIA  20270.0      FR         2B
# 3  11 RUE ARISTIDE BERGES ;  PONT E CLAIX      NaN     NaN        NaN
# 4                         1          AAAA      NaN     NaN        NaN
#
#    longitude   latitude
# 0  -0.561474  44.849528
# 1        NaN        NaN
# 2   9.467566  42.129211
# 3        NaN        NaN
# 4        NaN        NaN
#
# Informations sur le DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301096 entries, 0 to 301095
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   agentId     301096 non-null  int64
#  1   name        301096 non-null  object
#  2   siret       227345 non-null  float64
#  3   address     238826 non-null  object
#  4   city        245994 non-null  object
#  5   zipcode     231111 non-null  float64
#  6   country     237927 non-null  object
#  7   department  231111 non-null  object
#  8   longitude   221770 non-null  float64
#  9   latitude    221770 non-null  float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 23.0+ MB
# None
#
# Statistiques descriptives:
#              agentId         siret        zipcode      longitude  \
# count  301096.000000  2.273450e+05  231111.000000  221770.000000
# mean   150547.500000  4.792050e+13   55579.017559       2.417239
# std     86919.072663  1.736632e+13   27445.814645      10.889162
# min         0.000000  1.000000e+13    1000.000000     -61.797760
# 25%     75273.750000  3.778396e+13   33300.000000       1.257339
# 50%    150547.500000  4.413175e+13   59650.000000       2.409610
# 75%    225821.250000  5.236367e+13   76410.000000       4.869852
# max    301095.000000  9.999904e+13   98870.000000      55.815824
#
#             latitude
# count  221770.000000
# mean       45.332781
# std         9.675416
# min       -21.386913
# 25%        44.841200
# 50%        47.360632
# 75%        48.857429
# max        51.078241
#
# Les données ont été corrigées et nettoyées. Nouveau fichier CSV enregistré à : Foppa1.1.2_csv/Agents_modifie.csv

# %%
# !git config --global user.name "simonsaifi"
# !git config --global user.email "simon.saifi2000@gmail.com"

# %%
# !git clone https://github.com/simonsaifi/App-BI.git
# Out:
# Cloning into 'App-BI'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# %cd App-BI/
# Out:
# /content/App-BI

# %%
from google.colab import drive
drive.mount('/content/drive')

# Replace `your_notebook.ipynb` with your notebook's name
# !cp "/content/drive/My Drive/Colab Notebooks/APP-BI.ipynb" "./your_notebook.ipynb"
